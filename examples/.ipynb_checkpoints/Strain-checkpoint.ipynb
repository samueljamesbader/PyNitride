# %%
# %matplotlib notebook
import numpy as np
from numpy import r_
import matplotlib.pyplot as mpl
import matplotlib
matplotlib.rc('font',size=18)
import scipy.linalg as la
import scipy.interpolate as sciint
import contextlib

@contextlib.contextmanager
def printoptions(*args, **kwargs):
    original = np.get_printoptions()
    np.set_printoptions(*args, **kwargs)
    yield 
    np.set_printoptions(**original)

# %%
# Put the project directory on the path to make sure we can import PyNitride
import sys, os
sys.path.append(os.path.abspath("../"))

# %%
from pynitride import ParamDB
pmdb=ParamDB(units='neu')
to_units=pmdb.to_units
q,hbar,m_e=pmdb.get_constants("e,hbar,m_e")

# %%
a,c=pmdb.

# %%
a=3.189e-10 #m
c=5.189e-10 #m


C13oC33=108/374
st=(3.112-3.189)/3.189
sz=-2*C13oC33*st

A1=-7.21 * hbar**2/(2*m0)
A2=-.44 * hbar**2/(2*m0)
A3=6.68 * hbar**2/(2*m0)
A4=-3.46 * hbar**2/(2*m0)
A5=-3.4 * hbar**2/(2*m0)
A6=-4.9 * hbar**2/(2*m0)
A7=.0937e-10*q
D1=-3.7*q
D2=4.5*q
D3=8.2*q
D4=-4.1*q
D5=-4*q
D6=-5.5*q
acz=-4.9*q+D1  # OOPS THIS IS ACTUALLY az, not acz, correct by adding D1
act=-11.3*q+D2 # actually not so sure about that correction
mez=.2*m0
met=.2*m0

Deltacr=.01*q # VM
DeltaSO=.017*q # VM
#Deltacr=.021*q
#DeltaSO=0
#A7=.094e-10*q


Delta1=Deltacr
Delta2=DeltaSO/3
Delta3=DeltaSO/3
Delta=np.sqrt(2)*Delta3

def H66(k,e):
    kx,ky,kz=k
    exx,eyy,ezz=e
    
    #92 again
    Lambda=(A1*kz**2+A2*(kx**2+ky**2))+D1*ezz+D2*(exx+eyy)
    Theta=(A3*kz**2+A4*(kx**2+ky**2))+D3*ezz+D4*(exx+eyy)
    F=Delta1+Delta2+Lambda+Theta
    G=Delta1-Delta2+Lambda+Theta
    K=A5*(kx+1j*ky)**2
    H=(1j*A6*kz-A7)*(kx+1j*ky)
    I=(1j*A6*kz+A7)*(kx+1j*ky)
    
    hmat=np.matrix([
        [F,0, -H.conjugate(), 0, K.conjugate(), 0],
        [0, G, Delta, -H.conjugate(), 0, K.conjugate()],
        [-H, Delta, Lambda, 0, I.conjugate(), 0],
        [0, -H, 0, Lambda, Delta, I.conjugate()],
        [K, 0, I, Delta, G, 0],
        [0, K, 0, I, 0, F]])/q    
    return la.eigvalsh(hmat)

def Hcond(k,e):
    kx,ky,kz=k
    exx,eyy,ezz=e
    return np.array([hbar**2*(kx**2+ky**2)/(2*met)+hbar**2*kz**2/(2*mez)+acz*ezz+act*(exx+eyy)])/q

# %%
sz
# Out:
# 0.013944994742958322

# %%
st
# Out:
# -0.024145500156788947

# %%
def generate_path(points,n):
    points=[np.array(p) for p in points]
    return np.vstack(
            [np.array([np.linspace(0,1,n-1,endpoint=False)]).T*(pf-ps)+ps
        for ps,pf in zip(points[:-1],points[1:])]+[points[-1]])

# %%
kvecs=generate_path([[0,0,0]],n=1)

# %%
vbs_relaxed=np.array([H66(kvec,[0,0,0]) for kvec in kvecs])
vbs_strain=np.array([H66(kvec,[st,st,sz]) for kvec in kvecs])
cbs_relaxed=np.array([Hcond(kvec,[0,0,0]) for kvec in kvecs])
cbs_strain=np.array([Hcond(kvec,[st,st,sz]) for kvec in kvecs])

vbs_relaxed=vbs_relaxed-np.max(vbs_relaxed)
vbs_strain=vbs_strain-np.max(vbs_relaxed)

# %%
# How A theoretically moves
((D1+D3)*sz+(D2+D4)*(2*st))/q+.01
# Out:
# 0.05343607621788125

# %%
# How C theoretically moves
((D1)*sz)/q+((D2)*(2*st))/q
# Out:
# -0.26890598196004634

# %%
# How cond theoretically moves
(acz*sz+act*2*st)/q
# Out:
# 0.20845184734288819

# %%
# How gap theoretically changes
(acz-D1-D3)/q*sz+(act-D2-D4)/q*2*st
# Out:
# 0.1650157711250069

# %%
3.44+0.1650157711250069
# Out:
# 3.605015771125007

# %%
cbs_relaxed[0]-vbs_relaxed[0][0]
# Out:
# array([ 0.02180161])

# %%
# How cond-C actually moves
cbs_strain[0]-vbs_strain[0][0]-(cbs_relaxed[0]-vbs_relaxed[0][0])
# Out:
# array([ 0.45575889])

# %%
# How the gap actually changes
cbs_strain[0]-vbs_strain[0][5]-(cbs_relaxed[0]-vbs_relaxed[0][5])
# Out:
# array([ 0.1493491])

# %%
pa=np.pi/a

# %%
Delta/q
# Out:
# 0.0080138768534475397

# %%
vbs_relaxed[498]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-5e7899bee1fb> in <module>()
# ----> 1 vbs_relaxed[498]
#
# IndexError: index 498 is out of bounds for axis 0 with size 1

# %%
kmax=.15e10
kvecs=generate_path(points=[[0,0,kmax],[0,0,0],[kmax,0,0]],n=500)

# %%
vbs_relaxed=np.array([H66(kvec,[0,0,0]) for kvec in kvecs])
vbs_strain=np.array([H66(kvec,[st,st,sz]) for kvec in kvecs])
cbs_relaxed=np.array([Hcond(kvec,[0,0,0]) for kvec in kvecs])
cbs_strain=np.array([Hcond(kvec,[st,st,sz]) for kvec in kvecs])

vbs_relaxed=vbs_relaxed-np.max(vbs_relaxed)
vbs_strain=vbs_strain-np.max(vbs_relaxed)

# %%
mpl.figure(figsize=(6,9))
mpl.subplot(212)
pseudo_k=np.array([la.norm(kvec)*(-1 if kvec[2]!=0 else 1) for kvec in kvecs])

mpl.plot(pseudo_k/pa,vbs_relaxed,'b',label='relaxed')
mpl.plot(pseudo_k/pa,vbs_strain,'r',label='strained')
mpl.ylim(-.05,.0)
mpl.ylim(-.9,.1)
mpl.xlim(-.15,.15)
mpl.xlabel('            $\\leftarrow k_z, k_x\\rightarrow$   [$\pi/a_0$]')
mpl.xticks([-.15,.15])
mpl.ylabel('$E-E_{V0}$ [eV]')
mpl.subplot(211)
mpl.plot(pseudo_k/pa,cbs_relaxed,'b')
mpl.plot(pseudo_k/pa,cbs_strain,'r')
mpl.xticks([])
mpl.ylabel('$E-E_{C0}$ [eV]')
mpl.xlim(-.15,.15)
#mpl.ylim(0,.05)
mpl.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %%
#unstrained
p=500-1
for i in 2*np.arange(3):
    print("E0={:.3g}".format(bskx[0,i]))
    print("mx={:.3g}".format(-1/(2*m0/hbar**2*q*(bskx[p,i]-bskx[0,i])/k[p]**2)))
    print("mz={:.3g}".format(-1/(2*m0/hbar**2*q*(bskz[p,i]-bskz[0,i])/k[p]**2)))
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-2c1ff51ebdc1> in <module>()
#       2 p=500-1
#       3 for i in 2*np.arange(3):
# ----> 4     print("E0={:.3g}".format(bskx[0,i]))
#       5     print("mx={:.3g}".format(-1/(2*m0/hbar**2*q*(bskx[p,i]-bskx[0,i])/k[p]**2)))
#       6     print("mz={:.3g}".format(-1/(2*m0/hbar**2*q*(bskz[p,i]-bskz[0,i])/k[p]**2)))
#
# NameError: name 'bskx' is not defined

# %%
#strained
p=500-1
for i in 2*np.arange(3):
    print("E0={:.3g}".format(bskx_s[0,i]-bskx_s[0,5]))
    print("mx={:.3g}".format(-1/(2*m0/hbar**2*q*(bskx_s[p,i]-bskx_s[0,i])/k[p]**2)))
    print("mz={:.3g}".format(-1/(2*m0/hbar**2*q*(bskz_s[p,i]-bskz_s[0,i])/k[p]**2)))
    print("\n")
    
print((cbskz_s[0]-cbskz[0])-(bskz_s[0,5]-bskz[0,5]))
# Out:
# E0=-0.328
# mx=0.28
# mz=0.139
#
#
# E0=-0.0111
# mx=0.242
# mz=1.88
#
#
# E0=0
# mx=1.77
# mz=1.89
#
#
# [ 0.43392175]

# %%
i=1
whichbs=bskx
mpl.figure()
mpl.plot(k/pa,-hbar**2/np.gradient(np.gradient(q*(whichbs[:,i]-whichbs[0,i]),k[1]-k[0]),k[1]-k[0])/m0)
mpl.plot(k/pa,-hbar**2/(q*(whichbs[:,i]-whichbs[0,i])/k[:]**2)/(2*m0))
mpl.ylim(-1,3)
# Out:
# <img src="data:image/png;base64,...">
# -c:5: RuntimeWarning: invalid value encountered in true_divide
# (-1, 3)

# %%
kvecs=generate_path([[-1.5e10,0,0],[1.5e10,0,0]],500)

# %%
cbs_strain_qw=np.array([Hcond(kvec,[st,st,sz]) for kvec in kvecs])
cbs_strain_qw-=np.min(cbs_strain)
cbs_strain_qw=cbs_strain_qw+np.array([0.75506612,   1.32832039])

# %%
mpl.figure()
pseudo_k=np.array([kvec[0] for kvec in kvecs])
mpl.plot(pseudo_k/pa,cbs_strain_qw)
mpl.plot(pseudo_k/pa,.88+pseudo_k*0)
mpl.xlim(-.15,.15)
mpl.ylim(0,2)
mpl.xlabel('$k_x$')
mpl.ylabel('$E-E_{C}$')
mpl.legend(['Subband 1','Subband 2','Fermi Level'],loc='lower right')
# Out:
# <img src="data:image/png;base64,...">

# %%
cbs_strain
# Out:
# array([[ 0.63707483],
#        [ 0.63535862],
#        [ 0.63364586],
#        [ 0.63193654],
#        [ 0.63023066],
#        [ 0.62852823],
#        [ 0.62682923],
#        [ 0.62513368],
#        [ 0.62344158],
#        [ 0.62175291],
#        [ 0.62006769],
#        [ 0.61838591],
#        [ 0.61670758],
#        [ 0.61503268],
#        [ 0.61336123],
#        [ 0.61169322],
#        [ 0.61002866],
#        [ 0.60836753],
#        [ 0.60670986],
#        [ 0.60505562],
#        [ 0.60340482],
#        [ 0.60175747],
#        [ 0.60011356],
#        [ 0.5984731 ],
#        [ 0.59683607],
#        [ 0.59520249],
#        [ 0.59357236],
#        [ 0.59194566],
#        [ 0.59032241],
#        [ 0.5887026 ],
#        [ 0.58708623],
#        [ 0.58547331],
#        [ 0.58386383],
#        [ 0.58225779],
#        [ 0.58065519],
#        [ 0.57905604],
#        [ 0.57746033],
#        [ 0.57586806],
#        [ 0.57427923],
#        [ 0.57269385],
#        [ 0.57111191],
#        [ 0.56953342],
#        [ 0.56795836],
#        [ 0.56638675],
#        [ 0.56481858],
#        [ 0.56325386],
#        [ 0.56169257],
#        [ 0.56013473],
#        [ 0.55858034],
#        [ 0.55702938],
#        [ 0.55548187],
#        [ 0.5539378 ],
#        [ 0.55239717],
#        [ 0.55085999],
#        [ 0.54932625],
#        [ 0.54779595],
#        [ 0.54626909],
#        [ 0.54474568],
#        [ 0.54322571],
#        [ 0.54170918],
#        [ 0.5401961 ],
#        [ 0.53868646],
#        [ 0.53718026],
#        [ 0.5356775 ],
#        [ 0.53417819],
#        [ 0.53268232],
#        [ 0.53118989],
#        [ 0.5297009 ],
#        [ 0.52821536],
#        [ 0.52673326],
#        [ 0.5252546 ],
#        [ 0.52377939],
#        [ 0.52230762],
#        [ 0.52083929],
#        [ 0.5193744 ],
#        [ 0.51791296],
#        [ 0.51645496],
#        [ 0.5150004 ],
#        [ 0.51354928],
#        [ 0.51210161],
#        [ 0.51065738],
#        [ 0.50921659],
#        [ 0.50777925],
#        [ 0.50634535],
#        [ 0.50491489],
#        [ 0.50348787],
#        [ 0.5020643 ],
#        [ 0.50064417],
#        [ 0.49922748],
#        [ 0.49781423],
#        [ 0.49640443],
#        [ 0.49499807],
#        [ 0.49359515],
#        [ 0.49219568],
#        [ 0.49079965],
#        [ 0.48940706],
#        [ 0.48801791],
#        [ 0.48663221],
#        [ 0.48524995],
#        [ 0.48387113],
#        [ 0.48249576],
#        [ 0.48112383],
#        [ 0.47975534],
#        [ 0.47839029],
#        [ 0.47702868],
#        [ 0.47567052],
#        [ 0.4743158 ],
#        [ 0.47296453],
#        [ 0.4716167 ],
#        [ 0.47027231],
#        [ 0.46893136],
#        [ 0.46759385],
#        [ 0.46625979],
#        [ 0.46492917],
#        [ 0.46360199],
#        [ 0.46227826],
#        [ 0.46095797],
#        [ 0.45964112],
#        [ 0.45832772],
#        [ 0.45701775],
#        [ 0.45571123],
#        [ 0.45440815],
#        [ 0.45310852],
#        [ 0.45181233],
#        [ 0.45051958],
#        [ 0.44923027],
#        [ 0.44794441],
#        [ 0.44666199],
#        [ 0.44538301],
#        [ 0.44410747],
#        [ 0.44283538],
#        [ 0.44156673],
#        [ 0.44030152],
#        [ 0.43903976],
#        [ 0.43778144],
#        [ 0.43652656],
#        [ 0.43527512],
#        [ 0.43402713],
#        [ 0.43278258],
#        [ 0.43154147],
#        [ 0.4303038 ],
#        [ 0.42906958],
#        [ 0.4278388 ],
#        [ 0.42661146],
#        [ 0.42538757],
#        [ 0.42416712],
#        [ 0.42295011],
#        [ 0.42173654],
#        [ 0.42052642],
#        [ 0.41931974],
#        [ 0.4181165 ],
#        [ 0.4169167 ],
#        [ 0.41572035],
#        [ 0.41452744],
#        [ 0.41333798],
#        [ 0.41215195],
#        [ 0.41096937],
#        [ 0.40979023],
#        [ 0.40861453],
#        [ 0.40744228],
#        [ 0.40627347],
#        [ 0.4051081 ],
#        [ 0.40394618],
#        [ 0.4027877 ],
#        [ 0.40163266],
#        [ 0.40048106],
#        [ 0.3993329 ],
#        [ 0.39818819],
#        [ 0.39704692],
#        [ 0.3959091 ],
#        [ 0.39477472],
#        [ 0.39364377],
#        [ 0.39251628],
#        [ 0.39139222],
#        [ 0.39027161],
#        [ 0.38915444],
#        [ 0.38804071],
#        [ 0.38693043],
#        [ 0.38582359],
#        [ 0.38472019],
#        [ 0.38362023],
#        [ 0.38252372],
#        [ 0.38143065],
#        [ 0.38034102],
#        [ 0.37925484],
#        [ 0.3781721 ],
#        [ 0.3770928 ],
#        [ 0.37601694],
#        [ 0.37494453],
#        [ 0.37387556],
#        [ 0.37281003],
#        [ 0.37174794],
#        [ 0.3706893 ],
#        [ 0.3696341 ],
#        [ 0.36858234],
#        [ 0.36753403],
#        [ 0.36648915],
#        [ 0.36544773],
#        [ 0.36440974],
#        [ 0.3633752 ],
#        [ 0.36234409],
#        [ 0.36131644],
#        [ 0.36029222],
#        [ 0.35927145],
#        [ 0.35825412],
#        [ 0.35724023],
#        [ 0.35622979],
#        [ 0.35522278],
#        [ 0.35421923],
#        [ 0.35321911],
#        [ 0.35222244],
#        [ 0.3512292 ],
#        [ 0.35023942],
#        [ 0.34925307],
#        [ 0.34827017],
#        [ 0.34729071],
#        [ 0.34631469],
#        [ 0.34534212],
#        [ 0.34437299],
#        [ 0.3434073 ],
#        [ 0.34244505],
#        [ 0.34148625],
#        [ 0.34053089],
#        [ 0.33957897],
#        [ 0.33863049],
#        [ 0.33768546],
#        [ 0.33674387],
#        [ 0.33580572],
#        [ 0.33487102],
#        [ 0.33393976],
#        [ 0.33301194],
#        [ 0.33208756],
#        [ 0.33116663],
#        [ 0.33024914],
#        [ 0.32933509],
#        [ 0.32842449],
#        [ 0.32751733],
#        [ 0.32661361],
#        [ 0.32571333],
#        [ 0.3248165 ],
#        [ 0.3239231 ],
#        [ 0.32303316],
#        [ 0.32214665],
#        [ 0.32126359],
#        [ 0.32038397],
#        [ 0.31950779],
#        [ 0.31863505],
#        [ 0.31776576],
#        [ 0.31689991],
#        [ 0.31603751],
#        [ 0.31517854],
#        [ 0.31432302],
#        [ 0.31347094],
#        [ 0.31262231],
#        [ 0.23709717],
#        [ 0.23754301],
#        [ 0.23799229],
#        [ 0.23844501],
#        [ 0.23890117],
#        [ 0.23936078],
#        [ 0.23982383],
#        [ 0.24029032],
#        [ 0.24076025],
#        [ 0.24123363],
#        [ 0.24171045],
#        [ 0.24219071],
#        [ 0.24267441],
#        [ 0.24316156],
#        [ 0.24365215],
#        [ 0.24414619],
#        [ 0.24464366],
#        [ 0.24514458],
#        [ 0.24564894],
#        [ 0.24615675],
#        [ 0.24666799],
#        [ 0.24718268],
#        [ 0.24770082],
#        [ 0.24822239],
#        [ 0.24874741],
#        [ 0.24927587],
#        [ 0.24980777],
#        [ 0.25034312],
#        [ 0.25088191],
#        [ 0.25142414],
#        [ 0.25196982],
#        [ 0.25251893],
#        [ 0.25307149],
#        [ 0.2536275 ],
#        [ 0.25418694],
#        [ 0.25474983],
#        [ 0.25531616],
#        [ 0.25588593],
#        [ 0.25645915],
#        [ 0.25703581],
#        [ 0.25761591],
#        [ 0.25819946],
#        [ 0.25878644],
#        [ 0.25937687],
#        [ 0.25997075],
#        [ 0.26056806],
#        [ 0.26116882],
#        [ 0.26177302],
#        [ 0.26238066],
#        [ 0.26299175],
#        [ 0.26360628],
#        [ 0.26422425],
#        [ 0.26484567],
#        [ 0.26547052],
#        [ 0.26609883],
#        [ 0.26673057],
#        [ 0.26736575],
#        [ 0.26800438],
#        [ 0.26864645],
#        [ 0.26929197],
#        [ 0.26994092],
#        [ 0.27059332],
#        [ 0.27124917],
#        [ 0.27190845],
#        [ 0.27257118],
#        [ 0.27323735],
#        [ 0.27390696],
#        [ 0.27458002],
#        [ 0.27525652],
#        [ 0.27593646],
#        [ 0.27661984],
#        [ 0.27730667],
#        [ 0.27799694],
#        [ 0.27869065],
#        [ 0.27938781],
#        [ 0.2800884 ],
#        [ 0.28079244],
#        [ 0.28149993],
#        [ 0.28221085],
#        [ 0.28292522],
#        [ 0.28364303],
#        [ 0.28436429],
#        [ 0.28508898],
#        [ 0.28581712],
#        [ 0.28654871],
#        [ 0.28728373],
#        [ 0.2880222 ],
#        [ 0.28876411],
#        [ 0.28950946],
#        [ 0.29025826],
#        [ 0.2910105 ],
#        [ 0.29176618],
#        [ 0.29252531],
#        [ 0.29328787],
#        [ 0.29405388],
#        [ 0.29482334],
#        [ 0.29559623],
#        [ 0.29637257],
#        [ 0.29715235],
#        [ 0.29793557],
#        [ 0.29872224],
#        [ 0.29951235],
#        [ 0.3003059 ],
#        [ 0.30110289],
#        [ 0.30190333],
#        [ 0.30270721],
#        [ 0.30351454],
#        [ 0.3043253 ],
#        [ 0.30513951],
#        [ 0.30595716],
#        [ 0.30677825],
#        [ 0.30760279],
#        [ 0.30843077],
#        [ 0.30926219],
#        [ 0.31009706],
#        [ 0.31093536],
#        [ 0.31177711],
#        [ 0.31262231],
#        [ 0.31347094],
#        [ 0.31432302],
#        [ 0.31517854],
#        [ 0.31603751],
#        [ 0.31689991],
#        [ 0.31776576],
#        [ 0.31863505],
#        [ 0.31950779],
#        [ 0.32038397],
#        [ 0.32126359],
#        [ 0.32214665],
#        [ 0.32303316],
#        [ 0.3239231 ],
#        [ 0.3248165 ],
#        [ 0.32571333],
#        [ 0.32661361],
#        [ 0.32751733],
#        [ 0.32842449],
#        [ 0.32933509],
#        [ 0.33024914],
#        [ 0.33116663],
#        [ 0.33208756],
#        [ 0.33301194],
#        [ 0.33393976],
#        [ 0.33487102],
#        [ 0.33580572],
#        [ 0.33674387],
#        [ 0.33768546],
#        [ 0.33863049],
#        [ 0.33957897],
#        [ 0.34053089],
#        [ 0.34148625],
#        [ 0.34244505],
#        [ 0.3434073 ],
#        [ 0.34437299],
#        [ 0.34534212],
#        [ 0.34631469],
#        [ 0.34729071],
#        [ 0.34827017],
#        [ 0.34925307],
#        [ 0.35023942],
#        [ 0.3512292 ],
#        [ 0.35222244],
#        [ 0.35321911],
#        [ 0.35421923],
#        [ 0.35522278],
#        [ 0.35622979],
#        [ 0.35724023],
#        [ 0.35825412],
#        [ 0.35927145],
#        [ 0.36029222],
#        [ 0.36131644],
#        [ 0.36234409],
#        [ 0.3633752 ],
#        [ 0.36440974],
#        [ 0.36544773],
#        [ 0.36648915],
#        [ 0.36753403],
#        [ 0.36858234],
#        [ 0.3696341 ],
#        [ 0.3706893 ],
#        [ 0.37174794],
#        [ 0.37281003],
#        [ 0.37387556],
#        [ 0.37494453],
#        [ 0.37601694],
#        [ 0.3770928 ],
#        [ 0.3781721 ],
#        [ 0.37925484],
#        [ 0.38034102],
#        [ 0.38143065],
#        [ 0.38252372],
#        [ 0.38362023],
#        [ 0.38472019],
#        [ 0.38582359],
#        [ 0.38693043],
#        [ 0.38804071],
#        [ 0.38915444],
#        [ 0.39027161],
#        [ 0.39139222],
#        [ 0.39251628],
#        [ 0.39364377],
#        [ 0.39477472],
#        [ 0.3959091 ],
#        [ 0.39704692],
#        [ 0.39818819],
#        [ 0.3993329 ],
#        [ 0.40048106],
#        [ 0.40163266],
#        [ 0.4027877 ],
#        [ 0.40394618],
#        [ 0.4051081 ],
#        [ 0.40627347],
#        [ 0.40744228],
#        [ 0.40861453],
#        [ 0.40979023],
#        [ 0.41096937],
#        [ 0.41215195],
#        [ 0.41333798],
#        [ 0.41452744],
#        [ 0.41572035],
#        [ 0.4169167 ],
#        [ 0.4181165 ],
#        [ 0.41931974],
#        [ 0.42052642],
#        [ 0.42173654],
#        [ 0.42295011],
#        [ 0.42416712],
#        [ 0.42538757],
#        [ 0.42661146],
#        [ 0.4278388 ],
#        [ 0.42906958],
#        [ 0.4303038 ],
#        [ 0.43154147],
#        [ 0.43278258],
#        [ 0.43402713],
#        [ 0.43527512],
#        [ 0.43652656],
#        [ 0.43778144],
#        [ 0.43903976],
#        [ 0.44030152],
#        [ 0.44156673],
#        [ 0.44283538],
#        [ 0.44410747],
#        [ 0.44538301],
#        [ 0.44666199],
#        [ 0.44794441],
#        [ 0.44923027],
#        [ 0.45051958],
#        [ 0.45181233],
#        [ 0.45310852],
#        [ 0.45440815],
#        [ 0.45571123],
#        [ 0.45701775],
#        [ 0.45832772],
#        [ 0.45964112],
#        [ 0.46095797],
#        [ 0.46227826],
#        [ 0.46360199],
#        [ 0.46492917],
#        [ 0.46625979],
#        [ 0.46759385],
#        [ 0.46893136],
#        [ 0.47027231],
#        [ 0.4716167 ],
#        [ 0.47296453],
#        [ 0.4743158 ],
#        [ 0.47567052],
#        [ 0.47702868],
#        [ 0.47839029],
#        [ 0.47975534],
#        [ 0.48112383],
#        [ 0.48249576],
#        [ 0.48387113],
#        [ 0.48524995],
#        [ 0.48663221],
#        [ 0.48801791],
#        [ 0.48940706],
#        [ 0.49079965],
#        [ 0.49219568],
#        [ 0.49359515],
#        [ 0.49499807],
#        [ 0.49640443],
#        [ 0.49781423],
#        [ 0.49922748],
#        [ 0.50064417],
#        [ 0.5020643 ],
#        [ 0.50348787],
#        [ 0.50491489],
#        [ 0.50634535],
#        [ 0.50777925],
#        [ 0.50921659],
#        [ 0.51065738],
#        [ 0.51210161],
#        [ 0.51354928],
#        [ 0.5150004 ],
#        [ 0.51645496],
#        [ 0.51791296],
#        [ 0.5193744 ],
#        [ 0.52083929],
#        [ 0.52230762],
#        [ 0.52377939],
#        [ 0.5252546 ],
#        [ 0.52673326],
#        [ 0.52821536],
#        [ 0.5297009 ],
#        [ 0.53118989],
#        [ 0.53268232],
#        [ 0.53417819],
#        [ 0.5356775 ],
#        [ 0.53718026],
#        [ 0.53868646],
#        [ 0.5401961 ],
#        [ 0.54170918],
#        [ 0.54322571],
#        [ 0.54474568],
#        [ 0.54626909],
#        [ 0.54779595],
#        [ 0.54932625],
#        [ 0.55085999],
#        [ 0.55239717],
#        [ 0.5539378 ],
#        [ 0.55548187],
#        [ 0.55702938],
#        [ 0.55858034],
#        [ 0.56013473],
#        [ 0.56169257],
#        [ 0.56325386],
#        [ 0.56481858],
#        [ 0.56638675],
#        [ 0.56795836],
#        [ 0.56953342],
#        [ 0.57111191],
#        [ 0.57269385],
#        [ 0.57427923],
#        [ 0.57586806],
#        [ 0.57746033],
#        [ 0.57905604],
#        [ 0.58065519],
#        [ 0.58225779],
#        [ 0.58386383],
#        [ 0.58547331],
#        [ 0.58708623],
#        [ 0.5887026 ],
#        [ 0.59032241],
#        [ 0.59194566],
#        [ 0.59357236],
#        [ 0.59520249],
#        [ 0.59683607],
#        [ 0.5984731 ],
#        [ 0.60011356],
#        [ 0.60175747],
#        [ 0.60340482],
#        [ 0.60505562],
#        [ 0.60670986],
#        [ 0.60836753],
#        [ 0.61002866],
#        [ 0.61169322],
#        [ 0.61336123],
#        [ 0.61503268],
#        [ 0.61670758],
#        [ 0.61838591],
#        [ 0.62006769],
#        [ 0.62175291],
#        [ 0.62344158],
#        [ 0.62513368],
#        [ 0.62682923],
#        [ 0.62852823],
#        [ 0.63023066],
#        [ 0.63193654],
#        [ 0.63364586],
#        [ 0.63535862],
#        [ 0.63707483]])
