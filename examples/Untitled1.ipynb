# %%
# %matplotlib notebook
import sys, os
sys.path.append(os.path.abspath("../"))
import sam

# %%
from poissolve.context import *
from poissolve.materials import read_1dp_mat,Material
read_1dp_mat()

# %%
Material("GaN")._dict
# Out:
# {'DEc': 0.0,
#  'Eg': 3.4,
#  'Ei': 0,
#  'P': -0.21221131028003073,
#  'abbrev': 'GaN',
#  'barrier': {},
#  'dopants': {'Acceptor': {'E': 0.23, 'g': 4, 'type': 'Acceptor'},
#   'DeepAcceptor': {'E': 1.0, 'g': 4, 'type': 'Acceptor'},
#   'DeepDonor': {'E': 1.0, 'g': 2, 'type': 'Donor'},
#   'Donor': {'E': 0.015, 'g': 2, 'type': 'Donor'}},
#  'eps': 0.5250031936266393,
#  'ladder': {'electron': {'Gamma': {'DE': 0,
#     'g': 2.0,
#     'mdos': 1.1371260124182185,
#     'mxys': 1.1371260124182185,
#     'mzs': 1.1371260124182185}},
#   'hole': {'HH': {'DE': 0,
#     'g': 2.0,
#     'mdos': 7.959882086927529,
#     'mxys': 7.959882086927529,
#     'mzs': 7.959882086927529},
#    'LH': {'DE': 0,
#     'g': 2.0,
#     'mdos': 1.7056890186273275,
#     'mxys': 1.7056890186273275,
#     'mzs': 1.7056890186273275}}},
#  'name': 'GaN'}

# %%
Material("GaN")['P']
# Out:
# -0.21221131028003073

# %%
mpl.figure()
qwhemt=gan_qwhemt(2.5*nm,4.5*nm,25*nm,500*nm,1e16*cm**-3,surface=1*eV,snidermode=True)
Coupled_Schrodinger_Poisson(qwhemt,carriers=['electron','hole']).solve(rise=100)#low_act=5,rise=200,callback=stoppah)
plot_wavefunctions(qwhemt)
mpl.xlim(0,50)
#mpl.xlim(0,15)
#mpl.sca(mpl.gcf().get_axes()[0])
#mpl.ylim(-.5,2)
#mpl.hlines(y=0,xmin=0,xmax=100,color='r',linewidth=2)
# Out:
# <img src="data:image/png;base64,...">
# Semi-classical success (max err=7.7e-10)after 3 refinement iterations
# Full success (max err=5.1e-09)after 10 refinement iterations
# (0, 50)

# %%
qwhemt['n'].integrate()[-1]/(1e13/cm**2)
# Out:
# 1.575080746378781

# %%
qwhemt['p'].integrate()[-1]/(1e13/cm**2)
# Out:
# 4.5128336420061421
