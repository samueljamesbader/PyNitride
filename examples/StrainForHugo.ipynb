# %%
# Put the project directory on the path to make sure we can import PyNitride
import sys, os
sys.path.append(os.path.abspath("../"))

# %%
# %matplotlib notebook
import numpy as np
from scipy.linalg import norm
from pynitride import ParamDB, Material
from pynitride.bandstruct.kp import kp_6x6
from pynitride.bandstruct.reciprocal import generate_path
import matplotlib.pyplot as plt
pmdb=ParamDB(units='neu')
to_units=pmdb.to_units
q,hbar,m_e,nm=pmdb.get_constants("e,hbar,m_e,nm")
GaN=Material("GaN",pmdb=pmdb)
pa=np.pi/GaN['lattice.a']

# %%
GaN=Material("GaN")
AlN=Material("AlN")
a0=GaN['lattice.a']
c0=GaN['lattice.c']
a=AlN['lattice.a']
C13oC33=GaN['stiffness.C13']/GaN['stiffness.C33']
#C13oC33=108/374
st=(a-a0)/a0
sz=-2*C13oC33*st

# %%
kmax=1.5/nm
kvecs=generate_path(points=[[0,0,kmax],[0,0,0],[kmax,0,0]],n=500)
pseudo_k=np.array([norm(kvec)*(-1 if kvec[2]!=0 else 1) for kvec in kvecs])

# %%
bs_r_n=kp_6x6(GaN,kvecs,[0,0,0],spin_orbit=False)
bs_r_so=kp_6x6(GaN,kvecs,[0,0,0],spin_orbit=True)
bs_s_n=kp_6x6(GaN,kvecs,[st,st,sz],spin_orbit=False)
bs_s_so=kp_6x6(GaN,kvecs,[st,st,sz],spin_orbit=True)

# %%
def plot_bs(pseudo_k,bs,label='',color='',new_fig=True):
    if new_fig:
        plt.figure(figsize=(6,6))
    plt.subplot(212)

    plt.plot(pseudo_k/pa,bs[:,:6],color=color,label=label)
    plt.ylim(-.05,.0)
    plt.ylim(-.9,.1)
    plt.xlim(-.15,.15)
    plt.xlabel('            $\\leftarrow k_z, k_x\\rightarrow$   [$\pi/a_0$]')
    plt.xticks([-.15,.15])
    plt.ylabel('$E-E_{V0}$ [eV]')
    
    plt.subplot(211)
    plt.plot(pseudo_k/pa,bs[:,6:],color=color,label=label)
    plt.xticks([])
    plt.ylabel('$E-E_{C0}$ [eV]')
    plt.xlim(-.15,.15)
    #plt.ylim(0,.05)
    plt.tight_layout()

# %%
plot_bs(pseudo_k,bs_r_n,color='b')
plot_bs(pseudo_k,bs_r_so,color='r',new_fig=False)
plt.title("Relaxed: SO versus no SO")
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_bs(pseudo_k,bs_s_n,color='b')
plot_bs(pseudo_k,bs_s_so,color='r',new_fig=False)
plt.title("Strained: SO versus no SO")
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_bs(pseudo_k,bs_r_so,color='b')
plot_bs(pseudo_k,bs_s_so,color='r',new_fig=False)
plt.title("Relaxed vs Strained, SO")
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_bs(pseudo_k,bs_r_n,color='b')
plot_bs(pseudo_k,bs_s_n,color='r',new_fig=False)
plt.title("Relaxed vs Strained, no SO")
# Out:
# <img src="data:image/png;base64,...">

# %%
from scipy import gradient

# %%
def print_eff_mass(bs,k,p):
    n=len(k)
    for i in reversed(2*np.arange(3)):
        x=("E0={:7.3f}".format(bs[0,i]))
        x+=("     m={:7.3f}".format(-1/(2*m_e/hbar**2*(bs[p,i]-bs[0,i])/norm(k[p])**2)))
        x+=("     m'={:7.3f}".format(-hbar**2/(m_e*gradient(gradient(bs[:,i]))[p]/(norm(k[1,:])-norm(k[0]))**2)))
        print(x)
def plot_eff_mass(bs,k,i=4):
    #print(bs[:,i])
    m=-1/(2*m_e/hbar**2*(bs[:,i]-bs[0,i])/norm(k,axis=1)**2)
    mp=-hbar**2/(m_e*gradient(gradient(bs[:,i]))/(norm(k[1,:])-norm(k[0,:]))**2)
    print(m)
    print(mp)
    plt.plot(norm(k,axis=1),m)
    plt.plot(norm(k,axis=1),mp,'--')

# %%
plt.figure()
plt.plot(norm(kvecs[499:],axis=1),(bs_r_so[499:][:,4]))
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plot_eff_mass(bs_s_so[499:],kvecs[499:])
# Out:
# <img src="data:image/png;base64,...">
# [        nan  0.25688955  0.2569316   0.25702071  0.25715702  0.25734067
#   0.25757189  0.25785095  0.25817817  0.25855392  0.25897862  0.25945275
#   0.25997681  0.26055139  0.2611771   0.26185461  0.26258463  0.2633679
#   0.26420525  0.2650975   0.26604553  0.26705028  0.2681127   0.26923378
#   0.27041454  0.27165604  0.27295936  0.27432559  0.27575587  0.27725131
#   0.27881306  0.28044228  0.2821401   0.28390769  0.28574618  0.28765669
#   0.28964032  0.29169815  0.29383122  0.29604054  0.29832707  0.30069172
#   0.30313535  0.30565876  0.30826268  0.31094777  0.3137146   0.31656368
#   0.31949543  0.32251017  0.32560814  0.32878949  0.33205426  0.33540241
#   0.33883379  0.34234815  0.34594516  0.34962437  0.35338526  0.3572272
#   0.36114948  0.36515128  0.36923173  0.37338986  0.37762463  0.38193491
#   0.38631954  0.39077725  0.39530675  0.39990668  0.40457562  0.40931213
#   0.41411472  0.41898185  0.42391196  0.42890348  0.43395479  0.43906426
#   0.44423026  0.44945112  0.45472519  0.46005081  0.46542629  0.47084998
#   0.47632022  0.48183534  0.48739369  0.49299365  0.49863357  0.50431184
#   0.51002687  0.51577708  0.5215609   0.52737678  0.5332232   0.53909866
#   0.54500167  0.55093078  0.55688453  0.56286152  0.56886036  0.57487968
#   0.58091814  0.58697441  0.5930472   0.59913525  0.60523731  0.61135215
#   0.61747858  0.62361544  0.62976156  0.63591584  0.64207718  0.64824449
#   0.65441674  0.66059288  0.66677193  0.67295291  0.67913484  0.68531681
#   0.6914979   0.69767722  0.70385391  0.71002712  0.71619602  0.72235981
#   0.72851772  0.73466897  0.74081283  0.74694858  0.75307551  0.75919294
#   0.76530021  0.77139667  0.77748169  0.78355467  0.78961501  0.79566214
#   0.80169551  0.80771457  0.8137188   0.81970769  0.82568075  0.83163751
#   0.8375775   0.84350028  0.84940541  0.85529249  0.86116111  0.86701088
#   0.87284142  0.87865238  0.88444341  0.89021417  0.89596433  0.9016936
#   0.90740166  0.91308823  0.91875304  0.92439583  0.93001633  0.93561431
#   0.94118954  0.94674179  0.95227085  0.95777653  0.96325862  0.96871695
#   0.97415135  0.97956165  0.9849477   0.99030934  0.99564644  1.00095888
#   1.00624652  1.01150925  1.01674698  1.02195959  1.02714699  1.03230911
#   1.03744586  1.04255717  1.04764297  1.05270322  1.05773785  1.06274681
#   1.06773008  1.0726876   1.07761936  1.08252533  1.0874055   1.09225983
#   1.09708834  1.10189102  1.10666786  1.11141887  1.11614407  1.12084346
#   1.12551707  1.13016492  1.13478702  1.13938343  1.14395416  1.14849926
#   1.15301876  1.15751272  1.16198118  1.16642418  1.17084179  1.17523406
#   1.17960106  1.18394283  1.18825945  1.19255099  1.19681751  1.2010591
#   1.20527581  1.20946774  1.21363495  1.21777754  1.22189558  1.22598916
#   1.23005837  1.23410329  1.23812402  1.24212065  1.24609327  1.25004198
#   1.25396687  1.25786804  1.2617456   1.26559963  1.26943025  1.27323756
#   1.27702166  1.28078265  1.28452065  1.28823576  1.29192808  1.29559773
#   1.29924481  1.30286944  1.30647172  1.31005178  1.31360971  1.31714563
#   1.32065967  1.32415192  1.3276225   1.33107153  1.33449913  1.3379054
#   1.34129047  1.34465445  1.34799746  1.35131961  1.35462101  1.3579018
#   1.36116208  1.36440196  1.36762158  1.37082104  1.37400046  1.37715995
#   1.38029965  1.38341965  1.38652009  1.38960107  1.39266271  1.39570514
#   1.39872846  1.40173279  1.40471825  1.40768496  1.41063302  1.41356256
#   1.4164737   1.41936654  1.4222412   1.42509779  1.42793644  1.43075725
#   1.43356033  1.4363458   1.43911378  1.44186437  1.44459769  1.44731384
#   1.45001295  1.45269512  1.45536045  1.45800907  1.46064108  1.46325658
#   1.4658557   1.46843853  1.47100518  1.47355577  1.47609039  1.47860915
#   1.48111217  1.48359954  1.48607137  1.48852776  1.49096883  1.49339466
#   1.49580537  1.49820105  1.50058181  1.50294775  1.50529896  1.50763556
#   1.50995763  1.51226529  1.51455862  1.51683772  1.5191027   1.52135364
#   1.52359065  1.52581382  1.52802324  1.53021901  1.53240123  1.53456998
#   1.53672537  1.53886747  1.54099639  1.54311222  1.54521504  1.54730495
#   1.54938204  1.55144639  1.55349809  1.55553723  1.55756391  1.55957819
#   1.56158018  1.56356996  1.56554761  1.56751321  1.56946686  1.57140863
#   1.5733386   1.57525687  1.5771635   1.57905859  1.58094221  1.58281444
#   1.58467537  1.58652506  1.58836361  1.59019109  1.59200757  1.59381313
#   1.59560785  1.59739181  1.59916507  1.60092772  1.60267983  1.60442147
#   1.60615272  1.60787365  1.60958432  1.61128482  1.61297522  1.61465557
#   1.61632597  1.61798646  1.61963713  1.62127804  1.62290927  1.62453087
#   1.62614291  1.62774547  1.6293386   1.63092238  1.63249687  1.63406213
#   1.63561823  1.63716524  1.6387032   1.6402322   1.64175229  1.64326353
#   1.64476599  1.64625972  1.64774479  1.64922125  1.65068917  1.65214861
#   1.65359962  1.65504226  1.6564766   1.65790268  1.65932057  1.66073032
#   1.66213199  1.66352564  1.66491132  1.66628908  1.66765898  1.66902107
#   1.67037542  1.67172206  1.67306106  1.67439247  1.67571633  1.67703271
#   1.67834165  1.6796432   1.68093742  1.68222435  1.68350405  1.68477656
#   1.68604193  1.68730022  1.68855147  1.68979572  1.69103304  1.69226345
#   1.69348702  1.69470379  1.69591379  1.69711709  1.69831372  1.69950374
#   1.70068718  1.70186409  1.70303451  1.70419849  1.70535608  1.7065073
#   1.70765222  1.70879087  1.70992329  1.71104952  1.71216961  1.7132836
#   1.71439153  1.71549343  1.71658936  1.71767934  1.71876343  1.71984165
#   1.72091405  1.72198067  1.72304155  1.72409672  1.72514622  1.72619009
#   1.72722837  1.72826109  1.72928829  1.73031001  1.73132629  1.73233715
#   1.73334264  1.7343428   1.73533765  1.73632723  1.73731157  1.73829072
#   1.7392647   1.74023356  1.74119731  1.742156    1.74310966  1.74405832
#   1.74500202  1.74594078  1.74687465  1.74780364  1.7487278   1.74964715
#   1.75056173  1.75147156  1.75237669  1.75327713  1.75417292  1.75506408
#   1.75595066  1.75683267  1.75771015  1.75858313  1.75945164  1.76031569
#   1.76117534  1.76203059  1.76288148  1.76372804  1.76457029  1.76540827
#   1.76624199  1.7670715   1.7678968   1.76871794  1.76953494  1.77034782
#   1.7711566   1.77196133]
# [   0.51394732    0.3427818     0.25738283    0.2580067     0.25892015
#     0.26012947    0.261643      0.26347125    0.26562707    0.26812582
#     0.27098562    0.27422761    0.27787634    0.28196013    0.28651156
#     0.2915681     0.29717277    0.30337501    0.31023168    0.31780833
#     0.32618067    0.33543642    0.34567762    0.3570234     0.36961352
#     0.38361282    0.39921684    0.41665908    0.43622038    0.45824123
#     0.48313822    0.51142607    0.54374796    0.58091771    0.62397976
#     0.6742964     0.73367765    0.80458052    0.89042509    0.99611562
#     1.12894112    1.30022188    1.52853847    1.8466558     2.31823808
#     3.08548691    4.54419901    8.36369302   43.66870774  -14.35373785
#    -6.333018     -4.13912882   -3.11938514   -2.53357766   -2.15583599
#    -1.89402115   -1.70352393   -1.56012725   -1.44955703   -1.36286154
#    -1.29414902   -1.23938945   -1.19573904   -1.16113949   -1.13407
#    -1.11338816   -1.0982248    -1.08791257   -1.0819364    -1.07989852
#    -1.08149318   -1.08648842   -1.09471256   -1.10604428   -1.12040534
#    -1.1377552    -1.15808722   -1.1814261    -1.20782627   -1.23737119
#    -1.27017344   -1.30637546   -1.34615109   -1.38970784   -1.43728991
#    -1.48918219   -1.54571521   -1.60727137   -1.67429264   -1.74728998
#    -1.82685508   -1.91367477   -2.00854909   -2.11241371   -2.22636835
#    -2.35171274   -2.48999277   -2.64306022   -2.81315099   -3.00298875
#    -3.21592434   -3.45612598   -3.72884341   -4.04078161   -4.40064127
#    -4.8199196    -5.31413054   -5.90472515   -6.62223056   -7.51161589
#    -8.64197601  -10.12521422  -12.15526795  -15.10014436  -19.75371054
#   -28.20244687  -48.26242282 -156.21603518  133.21234658   47.58834894
#    29.30145834   21.34040426   16.88693698   14.04274597   12.06997142
#    10.62201752    9.51456529    8.64055176    7.93353271    7.35008859
#     6.86064653    6.44436831    6.08614739    5.77476509    5.50171559
#     5.26043269    5.04576679    4.8536225     4.68070204    4.52432009
#     4.38226795    4.25271237    4.13411897    4.02519379    3.924838
#     3.83211243    3.74620966    3.66643166    3.59217193    3.52290095
#     3.45815439    3.39752334    3.34064633    3.28720265    3.23690674
#     3.18950354    3.14476452    3.10248432    3.0624779     3.0245781
#     2.9886335     2.95450666    2.92207252    2.89121706    2.86183608
#     2.83383421    2.80712397    2.78162496    2.75726322    2.73397052
#     2.7116839     2.69034511    2.66990021    2.65029917    2.63149553
#     2.6134461     2.59611066    2.5794517     2.56343424    2.54802559
#     2.53319517    2.51891436    2.50515631    2.49189585    2.47910934
#     2.46677457    2.45487063    2.44337783    2.43227763    2.42155254
#     2.41118604    2.40116253    2.39146728    2.38208632    2.37300647
#     2.36421521    2.35570068    2.34745164    2.33945742    2.33170787
#     2.32419336    2.31690474    2.30983328    2.30297069    2.29630907
#     2.28984089    2.28355898    2.27745647    2.27152685    2.26576387
#     2.26016156    2.25471424    2.24941646    2.244263      2.23924889
#     2.23436934    2.22961979    2.22499587    2.22049336    2.21610825
#     2.21183668    2.20767494    2.20361947    2.19966687    2.19581385
#     2.19205726    2.18839407    2.18482137    2.18133636    2.17793633
#     2.17461871    2.17138098    2.16822075    2.16513569    2.16212359
#     2.15918227    2.15630968    2.1535038     2.15076272    2.14808457
#     2.14546755    2.14290992    2.14041003    2.13796623    2.13557699
#     2.13324078    2.13095614    2.12872167    2.126536      2.12439782
#     2.12230584    2.12025884    2.11825562    2.11629501    2.11437592
#     2.11249724    2.11065793    2.10885697    2.10709338    2.1053662
#     2.10367451    2.10201741    2.10039402    2.09880352    2.09724507
#     2.09571789    2.09422119    2.09275425    2.09131633    2.08990672
#     2.08852475    2.08716974    2.08584106    2.08453807    2.08326018
#     2.08200678    2.0807773     2.07957119    2.0783879     2.07722691
#     2.07608769    2.07496975    2.07387261    2.07279579    2.07173884
#     2.0707013     2.06968274    2.06868274    2.06770088    2.06673677
#     2.06579001    2.06486022    2.06394703    2.06305009    2.06216903
#     2.06130352    2.06045322    2.05961781    2.05879697    2.05799039
#     2.05719777    2.05641882    2.05565325    2.05490077    2.05416113
#     2.05343404    2.05271927    2.05201654    2.05132561    2.05064625
#     2.04997822    2.04932129    2.04867523    2.04803983    2.04741487
#     2.04680015    2.04619547    2.04560061    2.0450154     2.04443964
#     2.04387315    2.04331574    2.04276724    2.04222748    2.04169629
#     2.0411735     2.04065895    2.04015249    2.03965396    2.03916322
#     2.03868011    2.03820449    2.03773622    2.03727516    2.03682118
#     2.03637416    2.03593395    2.03550043    2.03507348    2.03465299
#     2.03423883    2.03383088    2.03342904    2.0330332     2.03264324
#     2.03225906    2.03188056    2.03150763    2.03114018    2.03077812
#     2.03042133    2.03006974    2.02972325    2.02938177    2.02904522
#     2.0287135     2.02838654    2.02806425    2.02774655    2.02743337
#     2.02712462    2.02682023    2.02652013    2.02622424    2.0259325
#     2.02564482    2.02536115    2.02508142    2.02480555    2.02453349
#     2.02426518    2.02400055    2.02373953    2.02348208    2.02322813
#     2.02297762    2.02273051    2.02248672    2.02224622    2.02200894
#     2.02177484    2.02154385    2.02131595    2.02109106    2.02086915
#     2.02065017    2.02043407    2.02022081    2.02001034    2.01980261
#     2.01959759    2.01939523    2.0191955     2.01899834    2.01880372
#     2.0186116     2.01842194    2.01823471    2.01804986    2.01786737
#     2.01768718    2.01750928    2.01733362    2.01716017    2.0169889
#     2.01681977    2.01665275    2.01648781    2.01632492    2.01616405
#     2.01600517    2.01584825    2.01569326    2.01554016    2.01538895
#     2.01523957    2.01509202    2.01494626    2.01480226    2.01466001
#     2.01451947    2.01438062    2.01424343    2.01410789    2.01397396
#     2.01384163    2.01371088    2.01358167    2.01345399    2.01332782
#     2.01320313    2.01307991    2.01295813    2.01283777    2.01271881
#     2.01260124    2.01248503    2.01237017    2.01225664    2.01214441
#     2.01203347    2.01192381    2.0118154     2.01170822    2.01160227
#     2.01149752    2.01139396    2.01129157    2.01119034    2.01109024
#     2.01099127    2.01089341    2.01079665    2.01070096    2.01060634
#     2.01051277    2.01042024    2.01032873    2.01023823    2.01014872
#     2.0100602     2.00997266    2.00988606    2.00980042    2.0097157
#     2.00963191    2.00954902    2.00946703    2.00938593    2.0093057
#     2.00922633    2.00914782    2.00907014    2.00899329    2.00891727
#     2.00884205    2.00876763    2.00869399    2.00862114    2.00854905
#     2.00847773    2.00840715    2.00833731    2.0082682     2.00819981
#     2.00813213    2.00806516    2.00799888    2.00793329    2.00786838
#     2.00780413    2.00774055    2.00767761    2.00761532    2.00755367
#     2.00749265    2.00743225    2.00737246    2.67644381    4.01462626]

# %%
print("no SO")
print("x")
print_eff_mass(np.flipud(bs_r_n[:500]),np.flipud(kvecs[:500]),5)
print("y")
print_eff_mass((bs_r_n[499:]),(kvecs[499:]),5)
print("\n")
print("SO")
print("x")
print_eff_mass(np.flipud(bs_r_so[:500]),np.flipud(kvecs[:500]),5)
print("y")
print_eff_mass((bs_r_so[499:]),(kvecs[499:]),5)
# Out:
# no SO
# x
# E0=  0.000     m=  1.887     m'=  1.887
# E0=  0.000     m=  1.887     m'=  1.887
# E0= -0.010     m=  0.139     m'=  0.139
# y
# E0=  0.000     m=  2.000     m'=  2.000
# E0=  0.000     m=  0.146     m'=  0.147
# E0= -0.010     m=  1.107     m'=  1.091
#
#
# SO
# x
# E0=  0.000     m=  1.887     m'=  1.887
# E0= -0.005     m=  0.334     m'=  0.337
# E0= -0.022     m=  0.211     m'=  0.209
# y
# E0=  0.000     m=  0.269     m'=  0.264
# E0= -0.005     m=  0.054     m'=  0.322
# E0= -0.022     m=  0.057     m'=  0.527

# %% [markdown]
# strained
# ---

# %%
print("no SO")
print("x")
print_eff_mass(np.flipud(bs_s_n[:500]),np.flipud(kvecs[:500]),5)
print("y")
print_eff_mass((bs_s_n[499:]),(kvecs[499:]),5)
print("\n")
print("SO")
print("x")
print_eff_mass(np.flipud(bs_s_so[:500]),np.flipud(kvecs[:500]),5)
print("y")
print_eff_mass((bs_s_so[499:]),(kvecs[499:]),5)
# Out:
# no SO
# x
# E0=  0.039     m=  1.887     m'=  1.887
# E0=  0.039     m=  1.887     m'=  1.887
# E0= -0.275     m=  0.139     m'=  0.139
# y
# E0=  0.039     m=  2.000     m'=  2.000
# E0=  0.039     m=  0.137     m'=  0.137
# E0= -0.275     m=  2.199     m'=  2.199
#
#
# SO
# x
# E0=  0.039     m=  1.887     m'=  1.887
# E0=  0.027     m=  1.871     m'=  1.871
# E0= -0.281     m=  0.139     m'=  0.139
# y
# E0=  0.039     m=  0.257     m'=  0.260
# E0=  0.027     m=  0.210     m'=  0.253
# E0= -0.281     m=  0.764     m'=  2.186

# %% [markdown]
# strained at 100
# ---

# %%
print("SO")
print("x")
print_eff_mass(np.flipud(bs_s_so[:500]),np.flipud(kvecs[:500]),100)
print("y")
print_eff_mass((bs_s_so[499:]),(kvecs[499:]),100)
# Out:
# SO
# x
# E0=  0.039     m=  1.887     m'=  1.887
# E0=  0.027     m=  1.872     m'=  1.877
# E0= -0.281     m=  0.139     m'=  0.139
# y
# E0=  0.039     m=  0.569     m'= -3.216
# E0=  0.027     m=  0.164     m'=  0.124
# E0= -0.281     m=  1.983     m'=  2.089

# %%
bs_s_so[499][6]-bs_s_so[499][5]
# Out:
# 3.6168123414269675

# %%
bs_r_so[499][6]-bs_r_so[499][5]
# Out:
# 3.4376017699115038

# %%
bs_s_so[499][6]-bs_r_so[499][6]
# Out:
# 0.21777057126334043

# %%
Material("AlN")["Eg"]
# Out:
# 6.139999999999999

# %%
Material("AlN")["electron.DEc"]-(bs_s_so[499][6]-bs_r_so[499][6])
# Out:
# 1.6172294287366593

# %% [markdown]
# AlN
# ===

# %%
aln_bs_r_so=kp_6x6(AlN,kvecs,[0,0,0],spin_orbit=True)

# %%
plot_bs(pseudo_k,aln_bs_r_so,color='r')
#plot_bs(pseudo_k,bs_r_so,color='r',new_fig=False)
plt.title("Relaxed: SO")# versus no SO")
# Out:
# <div id='9987a64f-2154-4e4d-ac51-bad50e47b866'></div>

# %%
print("SO")
print("x")
print_eff_mass(np.flipud(aln_bs_r_so[:500]),np.flipud(kvecs[:500]),100)
print("z")
print_eff_mass((aln_bs_r_so[499:]),(kvecs[499:]),100)
# Out:
# SO
# x
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0781c1e60242> in <module>()
#       1 print("SO")
#       2 print("x")
# ----> 3 print_eff_mass(np.flipud(aln_bs_r_so[:500]),np.flipud(kvecs[:500]),100)
#       4 print("z")
#       5 print_eff_mass((aln_bs_r_so[499:]),(kvecs[499:]),100)
#
# NameError: name 'print_eff_mass' is not defined
